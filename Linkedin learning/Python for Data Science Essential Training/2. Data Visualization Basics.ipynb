# %% [markdown]
# ## 2.1 Create standard line, bar, and pie plots

# %%
import matplotlib.pyplot as plt, seaborn as sb, numpy as np, pandas as pd, matplotlib
from numpy.random import randn
from matplotlib import rcParams

# %matplotlib inline
sb.set_style('whitegrid')

# %%
matplotlib.rcParams['figure.figsize'] = 10, 8

# %% [markdown]
# ### create line chart from a list obj

# %%
x = range(1, 10)
y = [1,2,3,4,0,4,3,2,1]

# %%
plt.plot(x, y); plt.show()

# %% [markdown]
# ### create line chart from `pandas`

# %%
address = "./Ch01/01_05/mtcars.csv"
cars = pd.read_csv(address)
cars.columns = 'car_names mpg cyl disp hp drat wt qsec vs am gear carb'.split()
mpg = cars['mpg']

# %%
mpg.plot();plt.show()

# %%
df = cars[['cyl', 'wt', 'mpg']]
df.plot(); plt.show()

# %% [markdown]
# ### creating bar charts
#
# #### bar chart from a list

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### bar chart from `pandas`

# %%
mpg.plot(kind='bar')

# %%
mpg.plot(kind='barh')

# %% [markdown]
# ### pie chart

# %%
x = [1,2,3,4,0.5]
plt.pie(x)
plt.show()

# %% [markdown]
# ### saving a plot as an image file

# %%
plt.savefig('pie_chart.jpg')
plt.show()

# %% [markdown]
# ## 2.2 Define plot elements
#
# ### two methods for plot building
# 1. **functional method** - build plots by calling plotting function on varaible/set of variables
# 2. **object-oriented method** - build plot by first generating a blank 'figure' object and the populating the object with plots/plot elements
#
#
# *talked about method1 in last section*
#
# ### steps on oop
# 1. create blank figure object
# 2. add axes to the figure
# 3.

# %% [markdown]
# ## 2.4 Labels and Annotations
# * label plot features
# * adding legend
# * annotating plot
#
# ### two methods:
# 1. functional
# 2. object
#
# ### to annotate some features of the plot
# * `.annotate(xy, xytext, arrowprop)`
#
# #### parameters
# * `xy` = the location being annotated
# * `xytext` = the location of the text
# * `arrowprop` = draws an arrow from the text to the annotated point by giving a dictionary of arrow properties
#
# ### to add a legend:
# * `.legend(label, loc)`
#     * `label` = variable/category labels
#     * `loc` = location of legend

# %% [markdown]
# ### Labeling plot features
#
# #### The functional method

# %%
x = range(1, 10)
y = [1,2,3,4,0.5,4,3,2,1]
plt.bar(x, y)
plt.xlabel('your x-axis label'), plt.ylabel('your y-label')
# Out:
# (Text(0.5, 0, 'your x-axis label'), Text(0, 0.5, 'your y-label'))

# %%
z = [1, 2, 3, 4, 0.5]
veh_type = 'bicycle motorbike car van stroller'.split()
plt.pie(z, labels=veh_type); plt.show()

# %% [markdown]
# #### The object-oriented method

# %%
mpg = cars.mpg

fig = plt.figure() 
ax = fig.add_axes([.1, .1, 1, 1])

mpg.plot()
ax.set_xticks(range(32))
ax.set_xticklabels(cars.car_names, rotation=60, fontsize='medium')
ax.set_title('Miles per Gallon of Cars in mtcars'); ax.set_xlabel('car names'); ax.set_ylabel('miles/gal')
plt.show()

# %% [markdown]
# ### adding a legend to a plot
#
# #### functional

# %%
plt.pie(z)
plt.legend(veh_type, loc='best')
plt.show()

# %% [markdown]
# #### object oriented

# %%
fig = plt.figure()
ax = fig.add_axes([.1, .1, 1, 1])
mpg.plot()
ax.set_xticks(range(32))
ax.set_xticklabels(cars.car_names, rotation=60, fontsize='medium')
ax.set_title('Miles per Gallon of Cars in mtcars'); ax.set_xlabel('car names'); ax.set_ylabel('miles/gal')
ax.legend(loc='best');plt.show()

# %% [markdown]
# ### annotate the plot

# %%
mpg.max()
# Out:
# 33.9

# %%
fig = plt.figure()
ax = fig.add_axes([.1, .1, 1, 1])
mpg.plot()
ax.set_title('Miles per Gallon of Cars in mtcars'); ax.set_xlabel('car names'); ax.set_ylabel('miles/gal')

ax.set_ylim(0, 45)

ax.annotate('Toyota Corolla', xy=(19, 33.9), xytext=(22,35), arrowprops=dict(facecolor='black', shrink=0.5))
plt.show()

# %% [markdown]
# ## 2.5 Time Series

# %%
fileloc = './Ch02/02_05/Superstore-Sales.csv'
df = pd.read_csv(fileloc, index_col='Order Date', parse_dates=True, encoding='ansi')
df.head(1)
# Out:
#             Row ID  Order ID Order Priority  Order Quantity   Sales  Discount  \
# Order Date
# 2010-10-13       1         3            Low               6  261.54      0.04
#
#               Ship Mode  Profit  Unit Price  Shipping Cost  \
# Order Date
# 2010-10-13  Regular Air -213.25       38.94           35.0
#
#                  Customer Name Province   Region Customer Segment  \
# Order Date
# 2010-10-13  Muhammed MacIntyre  Nunavut  Nunavut   Small Business
#
#            Product Category    Product Sub-Category  \
# Order Date
# 2010-10-13  Office Supplies  Storage & Organization
#
#                                                 Product Name  \
# Order Date
# 2010-10-13  Eldon Base for stackable storage shelf, platinum
#
#            Product Container  Product Base Margin   Ship Date
# Order Date
# 2010-10-13         Large Box                  0.8  10/20/2010

# %%
df2 = df.sample(n=500, random_state=25, axis=0)
plt.xlabel('Order Date'); plt.ylabel('Order Quantity'); plt.title('Superstore Sales')
df2['Order Quantity'].plot()

# %% [markdown]
# ## 2.6 Create Histograms and Scatterplots

# %%
import pandas.plotting as pdplt

# %% [markdown]
# ### eyeball distributions with histograms

# %%
mpg = cars.mpg
mpg.plot(kind='hist'); plt.show()

# %% [markdown]
# ### seaborn is really good for statistical plotting

# %%
sb.distplot(mpg); plt.show()

# %% [markdown]
# ### scatterplot

# %%
cars.plot(kind='scatter', x='hp', y='mpg', c=['darkgray'], s=150); plt.show()

# %%
sb.regplot(x='hp', y='mpg', data=cars, scatter=True); plt.show()

# %% [markdown]
# ### scatter plot matrix

# %%
sb.pairplot(cars); plt.show()

# %%
cars_df = pd.DataFrame((cars.ix[:,(1,3,4,6)].values), columns='mpg disp hp wt'.split())
cars_target = cars.ix[:,9].values
target_names = [0,1]

cars_df['group'] = pd.Series(cars_target, dtype='category')
sb.pairplot(cars_df, hue='group', palette='hls'); plt.show()
# Out:
# C:\Users\aweaver\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# C:\Users\aweaver\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#
# C:\Users\aweaver\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# ...

# %% [markdown]
# ### boxplots

# %%
cars.boxplot(column='mpg', by='am')
cars.boxplot(column='wt', by='am')
plt.show()

# %%
sb.boxplot(x='am', y='mpg', data=cars, palette='hls'); plt.show()

# %%
fig = plt.figure(); ax = fig.add_axes([0.5,0.5,1,1]); plt.show()
